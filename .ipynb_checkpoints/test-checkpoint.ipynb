# %%
import pandas as pd

# %%
csv_file = "./csv/dummyfile.csv"
# save_data_from_file(csv_file,",",)

pd_dic = pd.read_csv(csv_file, sep=",")
#1行目がヘッダーの場合
final_dict = [dic for index, dic in pd_dic.to_dict(orient="index").items() if index!=0]
#それ以外
final_dict = [dic for index, dic in pd_dic.to_dict(orient="index").items()]

# %%
pd_dic = pd.read_csv(csv_file, sep=",")

# %%
data = {}
for index, dic in pd_dic.to_dict(orient="index").items():
    data["{}".format(index)] = dic 
# result = {"title":filename,"text": text,"file_format":"pdf"}
result = {"title":csv_file,"text": data,"file_format":"csv"}

# %%
result
# Out:
# {'title': './csv/dummyfile.csv',
#  'text': {'0': {'名前': '津田 沙知絵',
#    'ふりがな': 'つだ さちえ',
#    'アドレス': 'tsuda_sachie@example.com',
#    '性別': '女',
#    '年齢': 30,
#    '誕生日': '1992/8/18',
#    '婚姻': '既婚',
#    '都道府県': '埼玉県',
#    '携帯': '080-7685-2986',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '右ルー・せき止め派'},
#   '1': {'名前': '大河内 隆',
#    'ふりがな': 'おおこうち たかし',
#    'アドレス': 'ookouchi_takashi@example.com',
#    '性別': '男',
#    '年齢': 51,
#    '誕生日': '1971/9/25',
#    '婚姻': '既婚',
#    '都道府県': '大分県',
#    '携帯': '080-5083-5846',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '左ルー・ナン派'},
#   '2': {'名前': '岡本 広之',
#    'ふりがな': 'おかもと ひろゆき',
#    'アドレス': 'okamoto_hiroyuki@example.com',
#    '性別': '男',
#    '年齢': 73,
#    '誕生日': '1949/9/18',
#    '婚姻': '既婚',
#    '都道府県': '兵庫県',
#    '携帯': '090-5963-8741',
#    'キャリア': 'ソフトバンク',
#    'カレーの食べ方': '手前ルー・せき止め派'},
#   '3': {'名前': '川瀬 育子',
#    'ふりがな': 'かわせ いくこ',
#    'アドレス': 'kawase_ikuko@example.com',
#    '性別': '女',
#    '年齢': 31,
#    '誕生日': '1991/3/25',
#    '婚姻': '既婚',
#    '都道府県': '青森県',
#    '携帯': '080-3631-1943',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': 'ぶっかけ・ルー攻め派'},
#   '4': {'名前': '田沢 利夫',
#    'ふりがな': 'たざわ としお',
#    'アドレス': 'tazawa_toshio@example.com',
#    '性別': '男',
#    '年齢': 48,
#    '誕生日': '1974/5/30',
#    '婚姻': '既婚',
#    '都道府県': '大阪府',
#    '携帯': '080-5892-9008',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '左ルー・混ぜ混ぜ派'},
#   '5': {'名前': '児玉 洋介',
#    'ふりがな': 'こだま ようすけ',
#    'アドレス': 'kodama_yousuke@example.com',
#    '性別': '男',
#    '年齢': 72,
#    '誕生日': '1950/6/10',
#    '婚姻': '既婚',
#    '都道府県': '福岡県',
#    '携帯': '080-2613-8991',
#    'キャリア': 'ソフトバンク',
#    'カレーの食べ方': '右ルー・ルー攻め派'},
#   '6': {'名前': '進藤 桃子',
#    'ふりがな': 'しんどう ももこ',
#    'アドレス': 'shinndou_momoko@example.com',
#    '性別': '女',
#    '年齢': 28,
#    '誕生日': '1994/10/30',
#    '婚姻': '既婚',
#    '都道府県': '山口県',
#    '携帯': '080-4772-2508',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': 'ぶっかけ・せき止め派'},
#   '7': {'名前': '西本 研二',
#    'ふりがな': 'にしもと けんじ',
#    'アドレス': 'nishimoto_kenji@example.com',
#    '性別': '男',
#    '年齢': 27,
#    '誕生日': '1996/1/7',
#    '婚姻': '未婚',
#    '都道府県': '福岡県',
#    '携帯': '090-8872-6450',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': 'ぶっかけ・混ぜ混ぜ派'},
#   '8': {'名前': '柳川 えみ',
#    'ふりがな': 'やながわ えみ',
#    'アドレス': 'yanagawa_emi@example.com',
#    '性別': '女',
#    '年齢': 38,
#    '誕生日': '1984/9/6',
#    '婚姻': '既婚',
#    '都道府県': '兵庫県',
#    '携帯': '090-7733-9891',
#    'キャリア': 'ソフトバンク',
#    'カレーの食べ方': '左ルー・ルー攻め派'},
#   '9': {'名前': '白石 さんま',
#    'ふりがな': 'しらいし さんま',
#    'アドレス': 'shiraishi_sanma@example.com',
#    '性別': '男',
#    '年齢': 76,
#    '誕生日': '1947/1/27',
#    '婚姻': '既婚',
#    '都道府県': '京都府',
#    '携帯': '090-2828-9044',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': 'ぶっかけ・せき止め派'},
#   '10': {'名前': '宍戸 淳子',
#    'ふりがな': 'ししど あつこ',
#    'アドレス': 'shishido_atsuko@example.com',
#    '性別': '女',
#    '年齢': 66,
#    '誕生日': '1956/2/22',
#    '婚姻': '既婚',
#    '都道府県': '愛知県',
#    '携帯': '080-1438-6547',
#    'キャリア': 'au',
#    'カレーの食べ方': '右ルー・別口派'},
#   '11': {'名前': '中塚 ヒロ',
#    'ふりがな': 'なかづか ひろ',
#    'アドレス': 'nakaduka_hiro@example.com',
#    '性別': '男',
#    '年齢': 53,
#    '誕生日': '1969/5/9',
#    '婚姻': '既婚',
#    '都道府県': '埼玉県',
#    '携帯': '090- 975-5265',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '別盛り・別口派'},
#   '12': {'名前': '安部 景子',
#    'ふりがな': 'あべ けいこ',
#    'アドレス': 'abe_keiko@example.com',
#    '性別': '女',
#    '年齢': 68,
#    '誕生日': '1954/2/15',
#    '婚姻': '既婚',
#    '都道府県': '静岡県',
#    '携帯': '080- 502-6783',
#    'キャリア': 'ソフトバンク',
#    'カレーの食べ方': '右ルー・せき止め派'},
#   '13': {'名前': '阿部 瞬',
#    'ふりがな': 'あべ しゅん',
#    'アドレス': 'abe_shun@example.com',
#    '性別': '女',
#    '年齢': 40,
#    '誕生日': '1982/7/27',
#    '婚姻': '既婚',
#    '都道府県': '東京都',
#    '携帯': '080-9276-1999',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '右ルー・ルー攻め派'},
#   '14': {'名前': '唐沢 恵子',
#    'ふりがな': 'からさわ けいこ',
#    'アドレス': 'karasawa_keiko@example.com',
#    '性別': '女',
#    '年齢': 20,
#    '誕生日': '2002/4/30',
#    '婚姻': '未婚',
#    '都道府県': '大阪府',
#    '携帯': '090-9970-1591',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': 'ぶっかけ・ルー攻め派'},
#   '15': {'名前': '金井 瞬',
#    'ふりがな': 'かない しゅん',
#    'アドレス': 'kanai_shun@example.com',
#    '性別': '女',
#    '年齢': 80,
#    '誕生日': '1942/10/22',
#    '婚姻': '既婚',
#    '都道府県': '大阪府',
#    '携帯': '080-4783-8459',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': 'ぶっかけ・せき止め派'},
#   '16': {'名前': '安藤 慢太郎',
#    'ふりがな': 'あんどう まんたろう',
#    'アドレス': 'ando_mantarou@example.com',
#    '性別': '男',
#    '年齢': 23,
#    '誕生日': '2000/2/8',
#    '婚姻': '未婚',
#    '都道府県': '長野県',
#    '携帯': '090- 190- 159',
#    'キャリア': 'ソフトバンク',
#    'カレーの食べ方': 'ぶっかけ・せき止め派'},
#   '17': {'名前': '小笠原 知世',
#    'ふりがな': 'おがさわら ちせ',
#    'アドレス': 'ogasawara_chise@example.com',
#    '性別': '女',
#    '年齢': 37,
#    '誕生日': '1985/2/17',
#    '婚姻': '未婚',
#    '都道府県': '京都府',
#    '携帯': '080-2760-4396',
#    'キャリア': 'au',
#    'カレーの食べ方': '右ルー・せき止め派'},
#   '18': {'名前': '小野 洋',
#    'ふりがな': 'おの よう',
#    'アドレス': 'ono_you@example.com',
#    '性別': '男',
#    '年齢': 24,
#    '誕生日': '1998/12/16',
#    '婚姻': '既婚',
#    '都道府県': '群馬県',
#    '携帯': '090-4850-8808',
#    'キャリア': 'au',
#    'カレーの食べ方': '右ルー・混ぜ混ぜ派'},
#   '19': {'名前': '北田 遥',
#    'ふりがな': 'きただ はるか',
#    'アドレス': 'kitada_haruka@example.com',
#    '性別': '女',
#    '年齢': 52,
#    '誕生日': '1970/11/24',
#    '婚姻': '既婚',
#    '都道府県': '福岡県',
#    '携帯': '080-3313-4196',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '手前ルー・せき止め派'},
#   '20': {'名前': '坂口 ヒカル',
#    'ふりがな': 'さかぐち ひかる',
#    'アドレス': 'sakaguchi_hikaru@example.com',
#    '性別': '女',
#    '年齢': 37,
#    '誕生日': '1985/9/29',
#    '婚姻': '既婚',
#    '都道府県': '山口県',
#    '携帯': '080-5108-7545',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '左ルー・ルー攻め派'},
#   '21': {'名前': '河本 たまき',
#    'ふりがな': 'こうもと たまき',
#    'アドレス': 'koumoto_tamaki@example.com',
#    '性別': '女',
#    '年齢': 78,
#    '誕生日': '1944/4/2',
#    '婚姻': '既婚',
#    '都道府県': '神奈川県',
#    '携帯': '090-6512-7792',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '右ルー・ルー攻め派'},
#   '22': {'名前': '玉木 倫子',
#    'ふりがな': 'たまき のりこ',
#    'アドレス': 'tamaki_noriko@example.com',
#    '性別': '女',
#    '年齢': 50,
#    '誕生日': '1972/8/24',
#    '婚姻': '既婚',
#    '都道府県': '大阪府',
#    '携帯': '080-4970-5378',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '奥ルー・別口派'},
#   '23': {'名前': '浅野 美里',
#    'ふりがな': 'あさの みり',
#    'アドレス': 'asano_miri@example.com',
#    '性別': '女',
#    '年齢': 27,
#    '誕生日': '1995/12/1',
#    '婚姻': '未婚',
#    '都道府県': '石川県',
#    '携帯': '080-2188-4756',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': 'ぶっかけ・ルー攻め派'},
#   '24': {'名前': '高岡 あさみ',
#    'ふりがな': 'たかおか あさみ',
#    'アドレス': 'takaoka_asami@example.com',
#    '性別': '女',
#    '年齢': 65,
#    '誕生日': '1957/9/9',
#    '婚姻': '既婚',
#    '都道府県': '京都府',
#    '携帯': '080-6323-9244',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '左ルー・混ぜ混ぜ派'},
#   '25': {'名前': '浜 しぼり',
#    'ふりがな': 'はま しぼり',
#    'アドレス': 'hama_shibori@example.com',
#    '性別': '女',
#    '年齢': 28,
#    '誕生日': '1994/9/27',
#    '婚姻': '既婚',
#    '都道府県': '徳島県',
#    '携帯': '090-8483- 651',
#    'キャリア': 'au',
#    'カレーの食べ方': '左ルー・ナン派'},
#   '26': {'名前': '角田 一恵',
#    'ふりがな': 'かどた かづえ',
#    'アドレス': 'kadota_kadue@example.com',
#    '性別': '女',
#    '年齢': 24,
#    '誕生日': '1998/12/19',
#    '婚姻': '既婚',
#    '都道府県': '宮崎県',
#    '携帯': '090-8353-5309',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '手前ルー・ルー攻め派'},
#   '27': {'名前': '奈良 杏',
#    'ふりがな': 'なら あん',
#    'アドレス': 'nara_ann@example.com',
#    '性別': '女',
#    '年齢': 28,
#    '誕生日': '1994/7/22',
#    '婚姻': '既婚',
#    '都道府県': '東京都',
#    '携帯': '090-8072-6572',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': 'ぶっかけ・せき止め派'},
#   '28': {'名前': '三輪 竜次',
#    'ふりがな': 'みわ りゅうじ',
#    'アドレス': 'miwa_ryuuji@example.com',
#    '性別': '男',
#    '年齢': 26,
#    '誕生日': '1996/6/18',
#    '婚姻': '未婚',
#    '都道府県': '岡山県',
#    '携帯': '090-1051-4686',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '左ルー・せき止め派'},
#   '29': {'名前': '豊原 サンタマリア',
#    'ふりがな': 'とよはら さんたまりあ',
#    'アドレス': 'toyohara_stmaria@example.com',
#    '性別': '男',
#    '年齢': 73,
#    '誕生日': '1949/5/24',
#    '婚姻': '既婚',
#    '都道府県': '千葉県',
#    '携帯': '090-8429-8538',
#    'キャリア': 'ツーカー',
#    'カレーの食べ方': 'ぶっかけ・せき止め派'},
#   '30': {'名前': '大森 慢太郎',
#    'ふりがな': 'おおもり まんたろう',
#    'アドレス': 'oomori_mantarou@example.com',
#    '性別': '男',
#    '年齢': 64,
#    '誕生日': '1958/8/16',
#    '婚姻': '既婚',
#    '都道府県': '千葉県',
#    '携帯': '080-7994-1714',
#    'キャリア': 'au',
#    'カレーの食べ方': '左ルー・ルー攻め派'},
#   '31': {'名前': '草野 美希',
#    'ふりがな': 'くさの みき',
#    'アドレス': 'kusano_miki@example.com',
#    '性別': '女',
#    '年齢': 28,
#    '誕生日': '1994/4/19',
#    '婚姻': '既婚',
#    '都道府県': '福岡県',
#    '携帯': '080- 939-3123',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': 'ぶっかけ・せき止め派'},
#   '32': {'名前': '吉野 郁恵',
#    'ふりがな': 'よしの いくえ',
#    'アドレス': 'yoshino_ikue@example.com',
#    '性別': '女',
#    '年齢': 35,
#    '誕生日': '1987/5/1',
#    '婚姻': '既婚',
#    '都道府県': '愛知県',
#    '携帯': '080-9708-1967',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '右ルー・混ぜ混ぜ派'},
#   '33': {'名前': '保坂 裕次郎',
#    'ふりがな': 'ほさか ゆうじろう',
#    'アドレス': 'hosaka_yuujirou@example.com',
#    '性別': '男',
#    '年齢': 41,
#    '誕生日': '1981/9/26',
#    '婚姻': '既婚',
#    '都道府県': '東京都',
#    '携帯': '090-6045-7727',
#    'キャリア': 'au',
#    'カレーの食べ方': 'ぶっかけ・混ぜ混ぜ派'},
#   '34': {'名前': '永瀬 薫',
#    'ふりがな': 'ながせ かおる',
#    'アドレス': 'nagase_kaoru@example.com',
#    '性別': '女',
#    '年齢': 61,
#    '誕生日': '1962/1/19',
#    '婚姻': '既婚',
#    '都道府県': '青森県',
#    '携帯': '080-7299-8448',
#    'キャリア': 'au',
#    'カレーの食べ方': '左ルー・せき止め派'},
#   '35': {'名前': '松本 浩太郎',
#    'ふりがな': 'まつもと こうたろう',
#    'アドレス': 'matsumoto_koutarou@example.com',
#    '性別': '男',
#    '年齢': 76,
#    '誕生日': '1946/12/24',
#    '婚姻': '既婚',
#    '都道府県': '沖縄県',
#    '携帯': '080-8361-6725',
#    'キャリア': 'au',
#    'カレーの食べ方': 'ぶっかけ・ナン派'},
#   '36': {'名前': '葛西 なつみ',
#    'ふりがな': 'かさい なつみ',
#    'アドレス': 'kasai_natsumi@example.com',
#    '性別': '女',
#    '年齢': 54,
#    '誕生日': '1968/5/17',
#    '婚姻': '既婚',
#    '都道府県': '東京都',
#    '携帯': '080-1542-9058',
#    'キャリア': 'au',
#    'カレーの食べ方': 'ぶっかけ・ルー攻め派'},
#   '37': {'名前': '菊地 公顕',
#    'ふりがな': 'きくち きみあき',
#    'アドレス': 'kikuchi_kimiaki@example.com',
#    '性別': '男',
#    '年齢': 68,
#    '誕生日': '1954/5/15',
#    '婚姻': '既婚',
#    '都道府県': '東京都',
#    '携帯': '090-7079-  87',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': 'ぶっかけ・ルー攻め派'},
#   '38': {'名前': '畑 崇史',
#    'ふりがな': 'はたけ たかし',
#    'アドレス': 'hatake_takashi@example.com',
#    '性別': '男',
#    '年齢': 26,
#    '誕生日': '1996/5/28',
#    '婚姻': '既婚',
#    '都道府県': '神奈川県',
#    '携帯': '080-6396-1668',
#    'キャリア': 'ソフトバンク',
#    'カレーの食べ方': 'ぶっかけ・ナン派'},
#   '39': {'名前': '篠山 涼子',
#    'ふりがな': 'しのやま りょうこ',
#    'アドレス': 'shinoyama_ryouko@example.com',
#    '性別': '女',
#    '年齢': 62,
#    '誕生日': '1960/3/13',
#    '婚姻': '既婚',
#    '都道府県': '兵庫県',
#    '携帯': '090-5566-5959',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '左ルー・せき止め派'},
#   '40': {'名前': '高瀬 茂樹',
#    'ふりがな': 'たかせ しげき',
#    'アドレス': 'takase_shigeki@example.com',
#    '性別': '男',
#    '年齢': 71,
#    '誕生日': '1951/6/1',
#    '婚姻': '既婚',
#    '都道府県': '東京都',
#    '携帯': '080-7676-7024',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '左ルー・混ぜ混ぜ派'},
#   '41': {'名前': '影山 彩華',
#    'ふりがな': 'かげやま あやか',
#    'アドレス': 'kageyama_ayaka@example.com',
#    '性別': '女',
#    '年齢': 45,
#    '誕生日': '1977/5/18',
#    '婚姻': '既婚',
#    '都道府県': '和歌山県',
#    '携帯': '080-7280-8208',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '手前ルー・ルー攻め派'},
#   '42': {'名前': '岩淵 建',
#    'ふりがな': 'いわぶち けん',
#    'アドレス': 'iwabuchi_ken@example.com',
#    '性別': '男',
#    '年齢': 26,
#    '誕生日': '1996/4/26',
#    '婚姻': '未婚',
#    '都道府県': '北海道',
#    '携帯': '080-8153-5387',
#    'キャリア': 'au',
#    'カレーの食べ方': 'ぶっかけ・混ぜ混ぜ派'},
#   '43': {'名前': '河村 美月',
#    'ふりがな': 'かわむら みづき',
#    'アドレス': 'kawamura_miduki@example.com',
#    '性別': '女',
#    '年齢': 60,
#    '誕生日': '1962/11/15',
#    '婚姻': '既婚',
#    '都道府県': '京都府',
#    '携帯': '080-7759-9578',
#    'キャリア': 'ソフトバンク',
#    'カレーの食べ方': '奥ルー・せき止め派'},
#   '44': {'名前': '根本 耕司',
#    'ふりがな': 'ねもと こうじ',
#    'アドレス': 'nemoto_kouji@example.com',
#    '性別': '男',
#    '年齢': 70,
#    '誕生日': '1952/9/4',
#    '婚姻': '既婚',
#    '都道府県': '北海道',
#    '携帯': '090-4006-3347',
#    'キャリア': 'ソフトバンク',
#    'カレーの食べ方': '左ルー・混ぜ混ぜ派'},
#   '45': {'名前': '城咲 精児',
#    'ふりがな': 'しろさき せいじ',
#    'アドレス': 'shirosaki_seiji@example.com',
#    '性別': '男',
#    '年齢': 51,
#    '誕生日': '1971/9/2',
#    '婚姻': '既婚',
#    '都道府県': '北海道',
#    '携帯': '090-9114-9355',
#    'キャリア': 'au',
#    'カレーの食べ方': 'ぶっかけ・せき止め派'},
#   '46': {'名前': '長沢 ジョージ',
#    'ふりがな': 'ながさわ じょーじ',
#    'アドレス': 'nagasawa_george@example.com',
#    '性別': '男',
#    '年齢': 32,
#    '誕生日': '1990/4/12',
#    '婚姻': '未婚',
#    '都道府県': '岡山県',
#    '携帯': '090-4867-9655',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': '右ルー・せき止め派'},
#   '47': {'名前': '深井 ひとみ',
#    'ふりがな': 'ふかい ひとみ',
#    'アドレス': 'fukai_hitomi@example.com',
#    '性別': '女',
#    '年齢': 66,
#    '誕生日': '1956/11/1',
#    '婚姻': '既婚',
#    '都道府県': '愛知県',
#    '携帯': '080-1119-5287',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': 'ぶっかけ・ルー攻め派'},
#   '48': {'名前': '船橋 寛',
#    'ふりがな': 'ふなばし ひろし',
#    'アドレス': 'funabashi_hiroshi@example.com',
#    '性別': '男',
#    '年齢': 75,
#    '誕生日': '1947/11/15',
#    '婚姻': '既婚',
#    '都道府県': '群馬県',
#    '携帯': '080-9691-7200',
#    'キャリア': 'au',
#    'カレーの食べ方': '右ルー・別口派'},
#   '49': {'名前': '山内 恭子',
#    'ふりがな': 'やまのうち きょうこ',
#    'アドレス': 'yamanouchi_kyouko@example.com',
#    '性別': '女',
#    '年齢': 56,
#    '誕生日': '1966/2/23',
#    '婚姻': '既婚',
#    '都道府県': '熊本県',
#    '携帯': '090-3447-4799',
#    'キャリア': 'ドコモ',
#    'カレーの食べ方': 'ぶっかけ・ルー攻め派'}},
#  'file_format': 'csv'}

# %%
pd_dic.to_dict(orient="index").items()
# Out:
# dict_items([(0, {'名前': '津田 沙知絵', 'ふりがな': 'つだ さちえ', 'アドレス': 'tsuda_sachie@example.com', '性別': '女', '年齢': 30, '誕生日': '1992/8/18', '婚姻': '既婚', '都道府県': '埼玉県', '携帯': '080-7685-2986', 'キャリア': 'ドコモ', 'カレーの食べ方': '右ルー・せき止め派'}), (1, {'名前': '大河内 隆', 'ふりがな': 'おおこうち たかし', 'アドレス': 'ookouchi_takashi@example.com', '性別': '男', '年齢': 51, '誕生日': '1971/9/25', '婚姻': '既婚', '都道府県': '大分県', '携帯': '080-5083-5846', 'キャリア': 'ドコモ', 'カレーの食べ方': '左ルー・ナン派'}), (2, {'名前': '岡本 広之', 'ふりがな': 'おかもと ひろゆき', 'アドレス': 'okamoto_hiroyuki@example.com', '性別': '男', '年齢': 73, '誕生日': '1949/9/18', '婚姻': '既婚', '都道府県': '兵庫県', '携帯': '090-5963-8741', 'キャリア': 'ソフトバンク', 'カレーの食べ方': '手前ルー・せき止め派'}), (3, {'名前': '川瀬 育子', 'ふりがな': 'かわせ いくこ', 'アドレス': 'kawase_ikuko@example.com', '性別': '女', '年齢': 31, '誕生日': '1991/3/25', '婚姻': '既婚', '都道府県': '青森県', '携帯': '080-3631-1943', 'キャリア': 'ドコモ', 'カレーの食べ方': 'ぶっかけ・ルー攻め派'}), (4, {'名前': '田沢 利夫', 'ふりがな': 'たざわ としお', 'アドレス': 'tazawa_toshio@example.com', '性別': '男', '年齢': 48, '誕生日': '1974/5/30', '婚姻': '既婚', '都道府県': '大阪府', '携帯': '080-5892-9008', 'キャリア': 'ドコモ', 'カレーの食べ方': '左ルー・混ぜ混ぜ派'}), (5, {'名前': '児玉 洋介', 'ふりがな': 'こだま ようすけ', 'アドレス': 'kodama_yousuke@example.com', '性別': '男', '年齢': 72, '誕生日': '1950/6/10', '婚姻': '既婚', '都道府県': '福岡県', '携帯': '080-2613-8991', 'キャリア': 'ソフトバンク', 'カレーの食べ方': '右ルー・ルー攻め派'}), (6, {'名前': '進藤 桃子', 'ふりがな': 'しんどう ももこ', 'アドレス': 'shinndou_momoko@example.com', '性別': '女', '年齢': 28, '誕生日': '1994/10/30', '婚姻': '既婚', '都道府県': '山口県', '携帯': '080-4772-2508', 'キャリア': 'ドコモ', 'カレーの食べ方': 'ぶっかけ・せき止め派'}), (7, {'名前': '西本 研二', 'ふりがな': 'にしもと けんじ', 'アドレス': 'nishimoto_kenji@example.com', '性別': '男', '年齢': 27, '誕生日': '1996/1/7', '婚姻': '未婚', '都道府県': '福岡県', '携帯': '090-8872-6450', 'キャリア': 'ドコモ', 'カレーの食べ方': 'ぶっかけ・混ぜ混ぜ派'}), (8, {'名前': '柳川 えみ', 'ふりがな': 'やながわ えみ', 'アドレス': 'yanagawa_emi@example.com', '性別': '女', '年齢': 38, '誕生日': '1984/9/6', '婚姻': '既婚', '都道府県': '兵庫県', '携帯': '090-7733-9891', 'キャリア': 'ソフトバンク', 'カレーの食べ方': '左ルー・ルー攻め派'}), (9, {'名前': '白石 さんま', 'ふりがな': 'しらいし さんま', 'アドレス': 'shiraishi_sanma@example.com', '性別': '男', '年齢': 76, '誕生日': '1947/1/27', '婚姻': '既婚', '都道府県': '京都府', '携帯': '090-2828-9044', 'キャリア': 'ドコモ', 'カレーの食べ方': 'ぶっかけ・せき止め派'}), (10, {'名前': '宍戸 淳子', 'ふりがな': 'ししど あつこ', 'アドレス': 'shishido_atsuko@example.com', '性別': '女', '年齢': 66, '誕生日': '1956/2/22', '婚姻': '既婚', '都道府県': '愛知県', '携帯': '080-1438-6547', 'キャリア': 'au', 'カレーの食べ方': '右ルー・別口派'}), (11, {'名前': '中塚 ヒロ', 'ふりがな': 'なかづか ひろ', 'アドレス': 'nakaduka_hiro@example.com', '性別': '男', '年齢': 53, '誕生日': '1969/5/9', '婚姻': '既婚', '都道府県': '埼玉県', '携帯': '090- 975-5265', 'キャリア': 'ドコモ', 'カレーの食べ方': '別盛り・別口派'}), (12, {'名前': '安部 景子', 'ふりがな': 'あべ けいこ', 'アドレス': 'abe_keiko@example.com', '性別': '女', '年齢': 68, '誕生日': '1954/2/15', '婚姻': '既婚', '都道府県': '静岡県', '携帯': '080- 502-6783', 'キャリア': 'ソフトバンク', 'カレーの食べ方': '右ルー・せき止め派'}), (13, {'名前': '阿部 瞬', 'ふりがな': 'あべ しゅん', 'アドレス': 'abe_shun@example.com', '性別': '女', '年齢': 40, '誕生日': '1982/7/27', '婚姻': '既婚', '都道府県': '東京都', '携帯': '080-9276-1999', 'キャリア': 'ドコモ', 'カレーの食べ方': '右ルー・ルー攻め派'}), (14, {'名前': '唐沢 恵子', 'ふりがな': 'からさわ けいこ', 'アドレス': 'karasawa_keiko@example.com', '性別': '女', '年齢': 20, '誕生日': '2002/4/30', '婚姻': '未婚', '都道府県': '大阪府', '携帯': '090-9970-1591', 'キャリア': 'ドコモ', 'カレーの食べ方': 'ぶっかけ・ルー攻め派'}), (15, {'名前': '金井 瞬', 'ふりがな': 'かない しゅん', 'アドレス': 'kanai_shun@example.com', '性別': '女', '年齢': 80, '誕生日': '1942/10/22', '婚姻': '既婚', '都道府県': '大阪府', '携帯': '080-4783-8459', 'キャリア': 'ドコモ', 'カレーの食べ方': 'ぶっかけ・せき止め派'}), (16, {'名前': '安藤 慢太郎', 'ふりがな': 'あんどう まんたろう', 'アドレス': 'ando_mantarou@example.com', '性別': '男', '年齢': 23, '誕生日': '2000/2/8', '婚姻': '未婚', '都道府県': '長野県', '携帯': '090- 190- 159', 'キャリア': 'ソフトバンク', 'カレーの食べ方': 'ぶっかけ・せき止め派'}), (17, {'名前': '小笠原 知世', 'ふりがな': 'おがさわら ちせ', 'アドレス': 'ogasawara_chise@example.com', '性別': '女', '年齢': 37, '誕生日': '1985/2/17', '婚姻': '未婚', '都道府県': '京都府', '携帯': '080-2760-4396', 'キャリア': 'au', 'カレーの食べ方': '右ルー・せき止め派'}), (18, {'名前': '小野 洋', 'ふりがな': 'おの よう', 'アドレス': 'ono_you@example.com', '性別': '男', '年齢': 24, '誕生日': '1998/12/16', '婚姻': '既婚', '都道府県': '群馬県', '携帯': '090-4850-8808', 'キャリア': 'au', 'カレーの食べ方': '右ルー・混ぜ混ぜ派'}), (19, {'名 ...

# %%
type(pd_dic.to_dict(orient="index").items())
# Out:
# dict_items

# %%
data = {}

# %%
data = {}
for index, dic in pd_dic.to_dict(orient="index").items():
    data[index] = dic

# %%
data[0]
# Out:
# {'名前': '津田 沙知絵',
#  'ふりがな': 'つだ さちえ',
#  'アドレス': 'tsuda_sachie@example.com',
#  '性別': '女',
#  '年齢': 30,
#  '誕生日': '1992/8/18',
#  '婚姻': '既婚',
#  '都道府県': '埼玉県',
#  '携帯': '080-7685-2986',
#  'キャリア': 'ドコモ',
#  'カレーの食べ方': '右ルー・せき止め派'}
